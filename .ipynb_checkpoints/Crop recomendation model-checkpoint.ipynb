# %%
import pandas as pd
import numpy as np
import seaborn as sb
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
from numpy import set_printoptions 
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, LabelEncoder, OrdinalEncoder, LabelBinarizer,LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.tree import DecisionTreeClassifier  
from sklearn.ensemble import RandomForestClassifier  
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC  # Changed to classifier
from imblearn.over_sampling import SMOTE
from ipywidgets import Dropdown, FloatSlider, IntSlider, interact, fixed,interactive, fixed, interact_manual

# %%
path = r"C:\Users\Administrator\Documents\weed_detect\Dataset\crop data.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#           N     P     K  temperature   humidity        ph    rainfall  \
# 0      90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536
# 1      85.0  58.0  41.0    21.770462  80.319644  7.038096  226.655537
# 2      60.0  55.0  44.0    23.004459  82.320763  7.840207  263.964248
# 3      74.0  35.0  40.0    26.491096  80.158363  6.980401  242.864034
# 4      78.0  42.0  42.0    20.130175  81.604873  7.628473  262.717340
# ...     ...   ...   ...          ...        ...       ...         ...
# 2211  107.0  34.0  32.0    26.774637  66.413269  6.780064  177.774507
# 2212   99.0  15.0  27.0    27.417112  56.636362  6.086922  127.924610
# 2213  118.0  33.0  30.0    24.131797  67.225123  6.362608  173.322839
# 2214  117.0  32.0  34.0    26.272418  52.127394  6.758793  127.175293
# 2215  104.0  18.0  30.0    23.603016  60.396475  6.779833  140.937041
#
#          label
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
# ...        ...
# 2211     COFEE
# 2212    coffee
# 2213    coffee
# 2214    coffee
# 2215  coffee
#
# [2216 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2212 non-null   float64
#  1   P            2213 non-null   float64
#  2   K            2214 non-null   float64
#  3   temperature  2213 non-null   float64
#  4   humidity     2213 non-null   float64
#  5   ph           2215 non-null   float64
#  6   rainfall     2215 non-null   float64
#  7   label        2216 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 138.6+ KB

# %%
df.isna().sum()
# Out:
# N              4
# P              3
# K              2
# temperature    3
# humidity       3
# ph             1
# rainfall       1
# label          0
# dtype: int64

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# N [ 90.  85.  60.  74.  78.  69.  94.  89.  68.  91.  93.  77.  88.  76.
#   67.  83.  98.  66.  97.  84.  73.  92.  95.  99.  63.  62.  64.  82.
#   79.  65.  75.  71.  72.  70.  86.  61.  81.  80.  nan 100.  87.  96.
#   40.  23.  39.  22.  36.  32.  58.  59.  42.  28.  43.  27.  50.  25.
#   31.  26.  54.  57.  49.  46.  38.  35.  52.  44.  24.  29.  20.  56.
#   37.  51.  41.  34.  30.  33.  47.  53.  45.  48.  13.   2.  17.  12.
#    6.  10.  19.  11.  18.  21.  16.   9.   1.   7.   8.   0.   3.   4.
#    5.  14.  15.  55. 105. 108. 118. 101. 106. 109. 117. 114. 110. 112.
#  111. 102. 116. 119. 107. 104. 103. 120. 113. 115. 133. 136. 126. 121.
#  129. 122. 140. 131. 135. 123. 125. 139. 132. 127. 130. 134.]
# P [ 42.  58.  55.  35.  37.  53.  54.  46.  56.  50.  48.  38.  45.  40.
#   59.  41.  47.  49.  51.  57.  39.  43.  44.  60.  52.  36.  nan  72.
#   67.  73.  70.  62.  74.  66.  63.  71.  78.  80.  68.  65.  77.  76.
#   79.  61.  64.  69.  75.  24.  18.  26.  27.  25.  21.  30.  11.   5.
#   10.   7.  20.  22.  15.  23.   8.  16.  29.  17.   6.  19.  13.   9.
#   14.  28.  94.  95.  92.  89.  88.  87.  85.  86.  83.  91.  81.  84.
#   90.  82.  93.  33.  31.  34.  32. 130. 144. 123. 125. 131. 140. 122.
#  134. 145. 139. 141. 138. 136. 132. 133. 121. 126. 142. 135. 129. 128.
#  137. 127. 120. 124. 143.  12.]
# K [ 43.  41.  44.  40.  42.  38.  36.  37.  39.  35.  45.  16.  17.  21.
#   20.  19.  25.  22.  15.  18.  23.  24.  77.  84.  85.  81.  75.  79.
#   76.  83.  78.  80.  82.  46.  50.  53.  54.  49.  55.  52.  47.  48.
#   51.  27.  31.  32.  34.  33.  30.  28.  29.  26. 195. 204. 205. 196.
#  198. 197. 203. 201. 202. 199. 200.  nan  12.  13.   6.   9.  10.  14.
#    8.   7.   5.  11.]
# temperature [20.87974371 21.77046169 23.00445915 ... 24.13179691 26.2724184
#  23.60301571]
# humidity [82.00274423 80.31964408 82.3207629  ... 67.22512329 52.12739421
#  60.39647474]
# ph [6.50298529 7.03809636 7.84020714 ... 6.36260785 6.75879255 6.77983261]
# rainfall [202.9355362 226.6555374 263.9642476 ... 173.3228386 127.1752928
#  140.9370415]
# label ['rice' 'RICE   ' 'rice  ' 'maize' 'chickpea' 'chickpeea' 'chick pea'
#  '   chickpea' 'kidneybeans' 'kidney  beans' 'kidneyb eans' 'pigeonpeas'
#  'mothbeans' 'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana'
#  'mango' 'grapes' 'watermelon' 'muskmelon' 'musk  melon' 'apple' 'orange'
#  'papaya' 'coconut' 'cotton' 'jute' 'coffee' 'CF' 'COFEE' 'coffee  ']

# %%
df['label'].replace(['RICE   ', 'rice  '], ['rice','rice'], inplace= True)
df['label'].replace(['chickpeea','chick pea', '   chickpea' ], ['chickpea','chickpea','chickpea'], inplace = True)
df['label'].replace(['kidney  beans', 'kidneyb eans'], ['kidneybeans','kidneybeans'], inplace = True)
df['label'].replace('musk  melon', 'muskmelon', inplace = True)
df['label'].replace(['CF', 'COFEE', 'coffee  '], ['coffee','coffee','coffee'], inplace = True)

# %%
df.label.unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df.drop_duplicates(inplace= True)

# %%
df.describe().T
# Out:
#               count        mean        std        min        25%        50%  \
# N            2196.0   50.490893  36.914374   0.000000  21.000000  37.000000
# P            2197.0   53.342740  32.971499   5.000000  28.000000  51.000000
# K            2198.0   48.147407  50.670912   5.000000  20.000000  32.000000
# temperature  2197.0   25.617883   5.065929   8.825675  22.770356  25.597049
# humidity     2197.0   71.469892  22.275296  14.258040  60.242186  80.471527
# ph           2199.0    6.469795   0.773973   3.504752   5.972052   6.425420
# rainfall     2199.0  103.484111  54.962511  20.211267  64.563449  94.953353
#
#                     75%         max
# N             84.000000  140.000000
# P             68.000000  145.000000
# K             49.000000  205.000000
# temperature   28.562122   43.675493
# humidity      89.984052   99.981876
# ph             6.923776    9.935091
# rainfall     124.308842  298.560117

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
corr = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']].corr()
plt.figure(figsize= [8,6])
sb.heatmap(corr, cmap= "YlGnBu", annot= True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=[8,6])
sb.scatterplot(data= df, x = 'temperature', y= 'humidity')
plt.title('humidity vs temperature')
plt.ylabel('humidity')
plt.xlabel('temperature');

# %%
plt.figure(figsize=[8,6])
sb.scatterplot(data= df, x = 'temperature', y= 'ph')
plt.title('humidity vs temperature')
plt.ylabel('humidity')
plt.xlabel('temperature');

# %%
plt.figure(figsize=[8,6])
sb.scatterplot(data= df, x = 'temperature', y= 'rainfall')
plt.title('humidity vs temperature')
plt.ylabel('rainfall')
plt.xlabel('temperature');

# %%
plt.figure(figsize= [12,8])
sb.boxplot(data= df, x = 'label', y= 'N', color= sb.color_palette()[0])
plt.xticks(rotation = 90);

# %%
plt.figure(figsize= [12,8])
sb.boxplot(data= df, x = 'label', y= 'P', color= sb.color_palette()[0])
plt.xticks(rotation = 90);

# %%
plt.figure(figsize= [12,8])
sb.boxplot(data= df, x = 'label', y= 'K', color= sb.color_palette()[0])
plt.xticks(rotation = 90);

# %%
df2 = df.dropna()

# %%
df2.isna().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.drop_duplicates(inplace= True)

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.describe().T
# Out:
#               count        mean        std        min        25%        50%  \
# N            2183.0   50.291342  36.821495   0.000000  21.000000  37.000000
# P            2183.0   53.415025  32.919185   5.000000  28.000000  51.000000
# K            2183.0   47.964727  50.526877   5.000000  20.000000  32.000000
# temperature  2183.0   25.614235   5.069143   8.825675  22.762243  25.595353
# humidity     2183.0   71.425431  22.285781  14.258040  60.187917  80.418180
# ph           2183.0    6.470332   0.776411   3.504752   5.968996   6.425931
# rainfall     2183.0  103.825225  54.995204  20.211267  64.777214  95.426260
#
#                     75%         max
# N             84.000000  140.000000
# P             68.000000  145.000000
# K             48.000000  205.000000
# temperature   28.565064   43.675493
# humidity      89.989011   99.981876
# ph             6.926608    9.935091
# rainfall     124.607331  298.560117

# %%
df2.shape
# Out:
# (2183, 8)

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df2.groupby('label').size()
# Out:
# label
# apple          100
# banana         100
# blackgram      100
# chickpea        99
# coconut        100
# coffee         100
# cotton         100
# grapes          97
# jute           100
# kidneybeans    100
# lentil         100
# maize           97
# mango          100
# mothbeans      100
# mungbean       100
# muskmelon       97
# orange         100
# papaya         100
# pigeonpeas     100
# pomegranate    100
# rice           100
# watermelon      93
# dtype: int64

# %%
df2.plot(kind = 'density', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
'''outliers = []
def detect_outliers_iqr(data):
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    # print(q1, q3)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    # print(lwr_bound, upr_bound)
    for i in data: 
        if (i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers# Driver code'''
# Out:
# 'outliers = []\ndef detect_outliers_iqr(data):\n    data = sorted(data)\n    q1 = np.percentile(data, 25)\n    q3 = np.percentile(data, 75)\n    # print(q1, q3)\n    IQR = q3-q1\n    lwr_bound = q1-(1.5*IQR)\n    upr_bound = q3+(1.5*IQR)\n    # print(lwr_bound, upr_bound)\n    for i in data: \n        if (i<lwr_bound or i>upr_bound):\n            outliers.append(i)\n    return outliers# Driver code'

# %%
df2.shape
# Out:
# (2183, 8)

# %%
'''sample_outliers = detect_outliers_iqr(df2['rainfall'])
df2.drop(df2[df2['rainfall'].isin(sample_outliers)].index, inplace=True)'''
# Out:
# "sample_outliers = detect_outliers_iqr(df2['rainfall'])\ndf2.drop(df2[df2['rainfall'].isin(sample_outliers)].index, inplace=True)"

# %%
df2.shape
# Out:
# (2183, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
'''sample_outliers = detect_outliers_iqr(df2['ph'])
df2.drop(df2[df2['ph'].isin(sample_outliers)].index, inplace=True)'''
# Out:
# "sample_outliers = detect_outliers_iqr(df2['ph'])\ndf2.drop(df2[df2['ph'].isin(sample_outliers)].index, inplace=True)"

# %%
df2.shape
# Out:
# (2183, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
'''sample_outliers = detect_outliers_iqr(df2['temperature'])
df2.drop(df2[df2['temperature'].isin(sample_outliers)].index, inplace=True)'''
# Out:
# "sample_outliers = detect_outliers_iqr(df2['temperature'])\ndf2.drop(df2[df2['temperature'].isin(sample_outliers)].index, inplace=True)"

# %%
df2.shape
# Out:
# (2183, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
'''sample_outliers = detect_outliers_iqr(df2['P'])
df2.drop(df2[df2['P'].isin(sample_outliers)].index, inplace=True)'''
# Out:
# "sample_outliers = detect_outliers_iqr(df2['P'])\ndf2.drop(df2[df2['P'].isin(sample_outliers)].index, inplace=True)"

# %%
df2.shape
# Out:
# (2183, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
df2.groupby('label').size()
# Out:
# label
# apple          100
# banana         100
# blackgram      100
# chickpea        99
# coconut        100
# coffee         100
# cotton         100
# grapes          97
# jute           100
# kidneybeans    100
# lentil         100
# maize           97
# mango          100
# mothbeans      100
# mungbean       100
# muskmelon       97
# orange         100
# papaya         100
# pigeonpeas     100
# pomegranate    100
# rice           100
# watermelon      93
# dtype: int64

# %%
df2.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
'''feature_df = df2.drop(columns=['label'])
label_df = df2.drop(columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])'''
# Out:
# "feature_df = df2.drop(columns=['label'])\nlabel_df = df2.drop(columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])"

# %%
'''oversample = SMOTE()
transformed_feature_df, transformed_label_df = oversample.fit_resample(feature_df, label_df)'''
# Out:
# 'oversample = SMOTE()\ntransformed_feature_df, transformed_label_df = oversample.fit_resample(feature_df, label_df)'

# %%
'''print(f'new label count: {transformed_label_df.value_counts()}')
print(f'old label count: {df2.label.value_counts()}')'''
# Out:
# "print(f'new label count: {transformed_label_df.value_counts()}')\nprint(f'old label count: {df2.label.value_counts()}')"

# %%
'''transformed_feature_df.head()'''
# Out:
# 'transformed_feature_df.head()'

# %%
'''transformed_df = pd.concat([transformed_feature_df,transformed_label_df],axis=1, join='outer')
transformed_df'''
# Out:
# "transformed_df = pd.concat([transformed_feature_df,transformed_label_df],axis=1, join='outer')\ntransformed_df"

# %%
'''transformed_df.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);'''
# Out:
# "transformed_df.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);"

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Encoding

# %%
df3 =  df2.copy()

# %%
'''encoder = LabelEncoder()
encoded_label = encoder.fit_transform(transformed_df['label'])
encoded_df2 = transformed_df.assign(label = encoded_label)'''
# Out:
# "encoder = LabelEncoder()\nencoded_label = encoder.fit_transform(transformed_df['label'])\nencoded_df2 = transformed_df.assign(label = encoded_label)"

# %%
encoder = LabelEncoder()
encoded_label = encoder.fit_transform(df3['label'])
encoded_df2 = df3.assign(label = encoded_label)

# %%
encoded_df2
# Out:
#           N     P     K  temperature   humidity        ph    rainfall  label
# 0      90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536     20
# 1      85.0  58.0  41.0    21.770462  80.319644  7.038096  226.655537     20
# 2      60.0  55.0  44.0    23.004459  82.320763  7.840207  263.964248     20
# 3      74.0  35.0  40.0    26.491096  80.158363  6.980401  242.864034     20
# 4      78.0  42.0  42.0    20.130175  81.604873  7.628473  262.717340     20
# ...     ...   ...   ...          ...        ...       ...         ...    ...
# 2211  107.0  34.0  32.0    26.774637  66.413269  6.780064  177.774507      5
# 2212   99.0  15.0  27.0    27.417112  56.636362  6.086922  127.924610      5
# 2213  118.0  33.0  30.0    24.131797  67.225123  6.362608  173.322839      5
# 2214  117.0  32.0  34.0    26.272418  52.127394  6.758793  127.175293      5
# 2215  104.0  18.0  30.0    23.603016  60.396475  6.779833  140.937041      5
#
# [2183 rows x 8 columns]

# %%
X = encoded_df2.drop(columns= ['label']).values
y = encoded_df2['label'].values

# %%
encoded_df2.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
target = ['label']

# %% [markdown]
# ## Splitting

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size= 0.20, random_state=7)

# %%
print('X_train shape', X_train.shape)
print('X_test shape', X_test.shape)
print('y_train shape', y_train.shape)
print('y_test shape', y_test.shape)
# Out:
# X_train shape (1746, 7)
# X_test shape (437, 7)
# y_train shape (1746,)
# y_test shape (437,)

# %% [markdown]
# ## Rescaling

# %%
scaler = MinMaxScaler().fit(X_train)
X_trainR = scaler.transform(X_train)
X_testR = scaler.transform(X_test)

# %%
X_trainR_df = pd.DataFrame(X_trainR, columns= features)
X_trainR_df
# Out:
#              N         P      K  temperature  humidity        ph  rainfall
# 0     0.778571  0.050000  0.215     0.592027  0.908351  0.518908  0.001979
# 1     0.235714  0.392857  0.050     0.577508  0.786395  0.486856  0.130411
# 2     0.250000  0.978571  0.990     0.354240  0.886326  0.387168  0.371614
# 3     0.071429  0.385714  0.050     0.602721  0.875442  0.456597  0.138875
# 4     0.142857  0.450000  0.090     0.479886  0.579725  0.680636  0.154381
# ...        ...       ...    ...          ...       ...       ...       ...
# 1741  0.192857  0.407143  0.360     0.268917  0.005281  0.497477  0.179525
# 1742  0.028571  0.057143  0.005     0.195308  0.933248  0.656960  0.291933
# 1743  0.257143  0.278571  0.080     0.467710  0.432480  0.163803  0.065657
# 1744  0.107143  0.857143  0.970     0.275506  0.773393  0.334356  0.178000
# 1745  0.450000  0.264286  0.080     0.414255  0.677445  0.371476  0.168461
#
# [1746 rows x 7 columns]

# %%
X_trainR_df.describe().T
# Out:
#               count      mean       std  min       25%       50%       75%  \
# N            1746.0  0.360305  0.262777  0.0  0.150000  0.264286  0.600000
# P            1746.0  0.346032  0.236356  0.0  0.164286  0.328571  0.450000
# K            1746.0  0.216578  0.253938  0.0  0.075000  0.135000  0.220000
# temperature  1746.0  0.483273  0.146680  0.0  0.400052  0.481494  0.566537
# humidity     1746.0  0.669653  0.260654  0.0  0.539136  0.773223  0.884698
# ph           1746.0  0.480914  0.123506  0.0  0.400032  0.473776  0.553755
# rainfall     1746.0  0.298608  0.196989  0.0  0.158188  0.269572  0.371567
#
#              max
# N            1.0
# P            1.0
# K            1.0
# temperature  1.0
# humidity     1.0
# ph           1.0
# rainfall     1.0

# %%
X_trainR_df.plot(kind = 'density', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %% [markdown]
# ## Normalizer

# %%
scaler = Normalizer().fit(X_trainR)
X_trainRN = scaler.transform(X_trainR)
X_testRN = scaler.transform(X_testR)

# %%
X_trainRN_df = pd.DataFrame(X_trainRN, columns= features)
X_trainRN_df
# Out:
#              N         P         K  temperature  humidity        ph  rainfall
# 0     0.537295  0.034505  0.148372     0.408560  0.626857  0.358101  0.001366
# 1     0.197921  0.329868  0.041983     0.484913  0.660308  0.408796  0.109502
# 2     0.139770  0.547101  0.553491     0.198049  0.495529  0.216459  0.207762
# 3     0.058054  0.313494  0.040638     0.489869  0.711526  0.371105  0.112872
# 4     0.126049  0.397054  0.079411     0.423423  0.511515  0.600553  0.136217
# ...        ...       ...       ...          ...       ...       ...       ...
# 1741  0.233084  0.492066  0.435090     0.325008  0.006382  0.601242  0.216971
# 1742  0.023892  0.047785  0.004181     0.163323  0.780415  0.549373  0.244125
# 1743  0.335609  0.363577  0.104412     0.610430  0.564450  0.213787  0.085692
# 1744  0.067701  0.541608  0.612919     0.174085  0.488688  0.211271  0.112474
# 1745  0.433885  0.254822  0.077135     0.399420  0.653186  0.358173  0.162429
#
# [1746 rows x 7 columns]

# %%
X_trainRN_df.describe().T
# Out:
#               count      mean       std  min       25%       50%       75%  \
# N            1746.0  0.282188  0.189540  0.0  0.126053  0.229101  0.460000
# P            1746.0  0.278973  0.171138  0.0  0.133625  0.254544  0.417428
# K            1746.0  0.158360  0.148532  0.0  0.071068  0.113993  0.160838
# temperature  1746.0  0.396193  0.127361  0.0  0.317788  0.383913  0.466851
# humidity     1746.0  0.521441  0.183299  0.0  0.466319  0.541726  0.641034
# ph           1746.0  0.396208  0.119865  0.0  0.315521  0.386716  0.469633
# rainfall     1746.0  0.241361  0.148318  0.0  0.115667  0.216540  0.342059
#
#                   max
# N            0.713167
# P            0.738638
# K            0.622229
# temperature  0.821160
# humidity     0.841590
# ph           0.784854
# rainfall     0.646355

# %%
X_trainRN_df.plot(kind = 'density', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
X_trainRN_dfLabel = X_trainRN_df.copy()
X_trainRN_dfLabel['label'] = y_train

# %%
X_trainRN_dfLabel
# Out:
#              N         P         K  temperature  humidity        ph  rainfall  \
# 0     0.537295  0.034505  0.148372     0.408560  0.626857  0.358101  0.001366
# 1     0.197921  0.329868  0.041983     0.484913  0.660308  0.408796  0.109502
# 2     0.139770  0.547101  0.553491     0.198049  0.495529  0.216459  0.207762
# 3     0.058054  0.313494  0.040638     0.489869  0.711526  0.371105  0.112872
# 4     0.126049  0.397054  0.079411     0.423423  0.511515  0.600553  0.136217
# ...        ...       ...       ...          ...       ...       ...       ...
# 1741  0.233084  0.492066  0.435090     0.325008  0.006382  0.601242  0.216971
# 1742  0.023892  0.047785  0.004181     0.163323  0.780415  0.549373  0.244125
# 1743  0.335609  0.363577  0.104412     0.610430  0.564450  0.213787  0.085692
# 1744  0.067701  0.541608  0.612919     0.174085  0.488688  0.211271  0.112474
# 1745  0.433885  0.254822  0.077135     0.399420  0.653186  0.358173  0.162429
#
#       label
# 0        15
# 1        14
# 2         0
# 3        14
# 4         2
# ...     ...
# 1741      3
# 1742     16
# 1743     13
# 1744      7
# 1745     11
#
# [1746 rows x 8 columns]

# %%
X_trainRN_dfLabel.groupby('label').size()
# Out:
# label
# 0     82
# 1     80
# 2     74
# 3     82
# 4     77
# 5     73
# 6     82
# 7     77
# 8     80
# 9     79
# 10    81
# 11    78
# 12    75
# 13    81
# 14    81
# 15    79
# 16    81
# 17    85
# 18    78
# 19    84
# 20    80
# 21    77
# dtype: int64

# %% [markdown]
# ## Multicolinearity

# %%
corr = X_trainRN_dfLabel.corr()
plt.figure(figsize= [8,6])
sb.heatmap(corr, cmap= "YlGnBu", annot= True)
# Out:
# <Axes: >

# %%
X_train = X_trainRN
X_test = X_testRN

# %%
# Spot-Check Algorithms
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# %%
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, shuffle=True, random_state=7)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.837911 (0.025356)
# LDA: 0.935878 (0.021168)
# KNN: 0.955356 (0.018705)
# CART: 0.936443 (0.022187)
# NB: 0.978821 (0.009580)
# SVM: 0.962213 (0.016025)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
model = GaussianNB()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
# Evaluate the model and print the results
print(classification_report(y_test, predictions))
print('F1-score: ', f1_score(y_test, predictions,average='micro'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 # Evaluate the model and print the results
# ----> 2 print(classification_report(y_test, predictions))
#       3 print('F1-score: ', f1_score(y_test, predictions,average='micro'))
#
# NameError: name 'classification_report' is not defined

# %%
df2.columns

# %%
def make_prediction(Nitrogen, Phosphorus, Calcium, temperature, humidity, ph, rainfall):
    data = {
        'Nitrogen': Nitrogen,
        'Posphorus': Phosphorus,
        'Calcium': Calcium,
        'temperature': temperature,
        'humidity': humidity,
        'ph': ph,
        'rainfall': rainfall,
    }
    
    df = pd.DataFrame(data, index=[0])
    
    # Assuming model is your trained model
    prediction = model.predict(df)
    
    # Inverse transform the predicted labels
    decoded_prediction = encoder.inverse_transform(prediction)
    
    return f"The crop that will do well: {decoded_prediction[0]}"

# %%
make_prediction(999, 355, 3777, 777, 44, 2, 12)

# %%
make_prediction(5, 10, 3, 777, 44, 2, 0)

# %%
df[df.isna().any(axis=1)]
