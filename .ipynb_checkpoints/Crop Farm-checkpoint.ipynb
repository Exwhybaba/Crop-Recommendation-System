# %%
import pandas as pd
import numpy as np
import seaborn as sb
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
from numpy import set_printoptions 
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, LabelEncoder, OrdinalEncoder, LabelBinarizer,LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.tree import DecisionTreeClassifier  
from sklearn.ensemble import RandomForestClassifier  
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC  # Changed to classifier
from imblearn.over_sampling import SMOTE
from ipywidgets import Dropdown, FloatSlider, IntSlider, interact, fixed,interactive, fixed, interact_manual

# %%
path = r"C:\Users\Administrator\Documents\weed_detect\Dataset\crop data.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#           N     P     K  temperature   humidity        ph    rainfall  \
# 0      90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536
# 1      85.0  58.0  41.0    21.770462  80.319644  7.038096  226.655537
# 2      60.0  55.0  44.0    23.004459  82.320763  7.840207  263.964248
# 3      74.0  35.0  40.0    26.491096  80.158363  6.980401  242.864034
# 4      78.0  42.0  42.0    20.130175  81.604873  7.628473  262.717340
# ...     ...   ...   ...          ...        ...       ...         ...
# 2211  107.0  34.0  32.0    26.774637  66.413269  6.780064  177.774507
# 2212   99.0  15.0  27.0    27.417112  56.636362  6.086922  127.924610
# 2213  118.0  33.0  30.0    24.131797  67.225123  6.362608  173.322839
# 2214  117.0  32.0  34.0    26.272418  52.127394  6.758793  127.175293
# 2215  104.0  18.0  30.0    23.603016  60.396475  6.779833  140.937041
#
#          label
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
# ...        ...
# 2211     COFEE
# 2212    coffee
# 2213    coffee
# 2214    coffee
# 2215  coffee
#
# [2216 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2212 non-null   float64
#  1   P            2213 non-null   float64
#  2   K            2214 non-null   float64
#  3   temperature  2213 non-null   float64
#  4   humidity     2213 non-null   float64
#  5   ph           2215 non-null   float64
#  6   rainfall     2215 non-null   float64
#  7   label        2216 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 138.6+ KB

# %%
df.isna().sum()
# Out:
# N              4
# P              3
# K              2
# temperature    3
# humidity       3
# ph             1
# rainfall       1
# label          0
# dtype: int64

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# N [ 90.  85.  60.  74.  78.  69.  94.  89.  68.  91.  93.  77.  88.  76.
#   67.  83.  98.  66.  97.  84.  73.  92.  95.  99.  63.  62.  64.  82.
#   79.  65.  75.  71.  72.  70.  86.  61.  81.  80.  nan 100.  87.  96.
#   40.  23.  39.  22.  36.  32.  58.  59.  42.  28.  43.  27.  50.  25.
#   31.  26.  54.  57.  49.  46.  38.  35.  52.  44.  24.  29.  20.  56.
#   37.  51.  41.  34.  30.  33.  47.  53.  45.  48.  13.   2.  17.  12.
#    6.  10.  19.  11.  18.  21.  16.   9.   1.   7.   8.   0.   3.   4.
#    5.  14.  15.  55. 105. 108. 118. 101. 106. 109. 117. 114. 110. 112.
#  111. 102. 116. 119. 107. 104. 103. 120. 113. 115. 133. 136. 126. 121.
#  129. 122. 140. 131. 135. 123. 125. 139. 132. 127. 130. 134.]
# P [ 42.  58.  55.  35.  37.  53.  54.  46.  56.  50.  48.  38.  45.  40.
#   59.  41.  47.  49.  51.  57.  39.  43.  44.  60.  52.  36.  nan  72.
#   67.  73.  70.  62.  74.  66.  63.  71.  78.  80.  68.  65.  77.  76.
#   79.  61.  64.  69.  75.  24.  18.  26.  27.  25.  21.  30.  11.   5.
#   10.   7.  20.  22.  15.  23.   8.  16.  29.  17.   6.  19.  13.   9.
#   14.  28.  94.  95.  92.  89.  88.  87.  85.  86.  83.  91.  81.  84.
#   90.  82.  93.  33.  31.  34.  32. 130. 144. 123. 125. 131. 140. 122.
#  134. 145. 139. 141. 138. 136. 132. 133. 121. 126. 142. 135. 129. 128.
#  137. 127. 120. 124. 143.  12.]
# K [ 43.  41.  44.  40.  42.  38.  36.  37.  39.  35.  45.  16.  17.  21.
#   20.  19.  25.  22.  15.  18.  23.  24.  77.  84.  85.  81.  75.  79.
#   76.  83.  78.  80.  82.  46.  50.  53.  54.  49.  55.  52.  47.  48.
#   51.  27.  31.  32.  34.  33.  30.  28.  29.  26. 195. 204. 205. 196.
#  198. 197. 203. 201. 202. 199. 200.  nan  12.  13.   6.   9.  10.  14.
#    8.   7.   5.  11.]
# temperature [20.87974371 21.77046169 23.00445915 ... 24.13179691 26.2724184
#  23.60301571]
# humidity [82.00274423 80.31964408 82.3207629  ... 67.22512329 52.12739421
#  60.39647474]
# ph [6.50298529 7.03809636 7.84020714 ... 6.36260785 6.75879255 6.77983261]
# rainfall [202.9355362 226.6555374 263.9642476 ... 173.3228386 127.1752928
#  140.9370415]
# label ['rice' 'RICE   ' 'rice  ' 'maize' 'chickpea' 'chickpeea' 'chick pea'
#  '   chickpea' 'kidneybeans' 'kidney  beans' 'kidneyb eans' 'pigeonpeas'
#  'mothbeans' 'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana'
#  'mango' 'grapes' 'watermelon' 'muskmelon' 'musk  melon' 'apple' 'orange'
#  'papaya' 'coconut' 'cotton' 'jute' 'coffee' 'CF' 'COFEE' 'coffee  ']

# %%
df['label'].replace(['RICE   ', 'rice  '], ['rice','rice'], inplace= True)
df['label'].replace(['chickpeea','chick pea', '   chickpea' ], ['chickpea','chickpea','chickpea'], inplace = True)
df['label'].replace(['kidney  beans', 'kidneyb eans'], ['kidneybeans','kidneybeans'], inplace = True)
df['label'].replace('musk  melon', 'muskmelon', inplace = True)
df['label'].replace(['CF', 'COFEE', 'coffee  '], ['coffee','coffee','coffee'], inplace = True)

# %%
df.

# %%
df2 = df.dropna()

# %%
df2.isna().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 16

# %%
df2.drop_duplicates(inplace= True)

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.describe().T
# Out:
#               count        mean        std        min        25%        50%  \
# N            2183.0   50.291342  36.821495   0.000000  21.000000  37.000000
# P            2183.0   53.415025  32.919185   5.000000  28.000000  51.000000
# K            2183.0   47.964727  50.526877   5.000000  20.000000  32.000000
# temperature  2183.0   25.614235   5.069143   8.825675  22.762243  25.595353
# humidity     2183.0   71.425431  22.285781  14.258040  60.187917  80.418180
# ph           2183.0    6.470332   0.776411   3.504752   5.968996   6.425931
# rainfall     2183.0  103.825225  54.995204  20.211267  64.777214  95.426260
#
#                     75%         max
# N             84.000000  140.000000
# P             68.000000  145.000000
# K             48.000000  205.000000
# temperature   28.565064   43.675493
# humidity      89.989011   99.981876
# ph             6.926608    9.935091
# rainfall     124.607331  298.560117

# %%
df2.shape
# Out:
# (2183, 8)

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df2.groupby('label').size()
# Out:
# label
# apple          100
# banana         100
# blackgram      100
# chickpea        99
# coconut        100
# coffee         100
# cotton         100
# grapes          97
# jute           100
# kidneybeans    100
# lentil         100
# maize           97
# mango          100
# mothbeans      100
# mungbean       100
# muskmelon       97
# orange         100
# papaya         100
# pigeonpeas     100
# pomegranate    100
# rice           100
# watermelon      93
# dtype: int64

# %%
df2.plot(kind = 'density', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
outliers = []
def detect_outliers_iqr(data):
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    # print(q1, q3)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    # print(lwr_bound, upr_bound)
    for i in data: 
        if (i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers# Driver code

# %%
df2.shape
# Out:
# (2183, 8)

# %%
sample_outliers = detect_outliers_iqr(df2['rainfall'])
df2.drop(df2[df2['rainfall'].isin(sample_outliers)].index, inplace=True)

# %%
df2.shape
# Out:
# (2084, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
sample_outliers = detect_outliers_iqr(df2['ph'])
df2.drop(df2[df2['ph'].isin(sample_outliers)].index, inplace=True)

# %%
df2.shape
# Out:
# (2027, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
sample_outliers = detect_outliers_iqr(df2['temperature'])
df2.drop(df2[df2['temperature'].isin(sample_outliers)].index, inplace=True)

# %%
df2.shape
# Out:
# (1948, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
sample_outliers = detect_outliers_iqr(df2['P'])
df2.drop(df2[df2['P'].isin(sample_outliers)].index, inplace=True)

# %%
df2.shape
# Out:
# (1854, 8)

# %%
df2.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
df2.groupby('label').size()
# Out:
# label
# apple           39
# banana         100
# blackgram      100
# chickpea        86
# coconut         86
# coffee         100
# cotton         100
# grapes          31
# jute           100
# kidneybeans    100
# lentil         100
# maize           97
# mango           98
# mothbeans       58
# mungbean       100
# muskmelon       97
# orange          83
# papaya          54
# pigeonpeas     100
# pomegranate    100
# rice            32
# watermelon      93
# dtype: int64

# %%
df2.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
feature_df = df2.drop(columns=['label'])
label_df = df2.drop(columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

# %%
oversample = SMOTE()
transformed_feature_df, transformed_label_df = oversample.fit_resample(feature_df, label_df)

# %%
print(f'new label count: {transformed_label_df.value_counts()}')
print(f'old label count: {df2.label.value_counts()}')
# Out:
# new label count: label
# apple          100
# banana         100
# rice           100
# pomegranate    100
# pigeonpeas     100
# papaya         100
# orange         100
# muskmelon      100
# mungbean       100
# mothbeans      100
# mango          100
# maize          100
# lentil         100
# kidneybeans    100
# jute           100
# grapes         100
# cotton         100
# coffee         100
# coconut        100
# chickpea       100
# blackgram      100
# watermelon     100
# Name: count, dtype: int64
# old label count: label
# coffee         100
# banana         100
# jute           100
# kidneybeans    100
# pigeonpeas     100
# cotton         100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# mango           98
# maize           97
# muskmelon       97
# watermelon      93
# coconut         86
# chickpea        86
# orange          83
# mothbeans       58
# papaya          54
# apple           39
# rice            32
# grapes          31
# Name: count, dtype: int64

# %%
transformed_feature_df.head()
# Out:
#       N     P     K  temperature   humidity        ph    rainfall
# 0  90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536
# 1  93.0  56.0  36.0    24.014976  82.056872  6.984354  185.277339
# 2  94.0  50.0  37.0    25.665852  80.663850  6.948020  209.586971
# 3  91.0  35.0  39.0    23.793920  80.418180  6.970860  206.261186
# 4  89.0  45.0  36.0    21.325042  80.474764  6.442475  185.497473

# %%
transformed_df = pd.concat([transformed_feature_df,transformed_label_df],axis=1, join='outer')
transformed_df
# Out:
#                N          P          K  temperature   humidity        ph  \
# 0      90.000000  42.000000  43.000000    20.879744  82.002744  6.502985
# 1      93.000000  56.000000  36.000000    24.014976  82.056872  6.984354
# 2      94.000000  50.000000  37.000000    25.665852  80.663850  6.948020
# 3      91.000000  35.000000  39.000000    23.793920  80.418180  6.970860
# 4      89.000000  45.000000  36.000000    21.325042  80.474764  6.442475
# ...          ...        ...        ...          ...        ...       ...
# 2195   83.536515  23.918535  51.691010    24.691443  81.200168  6.184308
# 2196  114.454431  20.010126  54.494937    25.970198  85.657426  6.782541
# 2197  112.749416  25.377046  54.374708    25.079361  86.134609  6.638630
# 2198   96.285352   9.750634  46.321338    25.546401  82.242377  6.427660
# 2199   98.721493   6.557014  46.671041    26.140777  86.542936  6.072931
#
#         rainfall       label
# 0     202.935536        rice
# 1     185.277339        rice
# 2     209.586971        rice
# 3     206.261186        rice
# 4     185.497473        rice
# ...          ...         ...
# 2195   44.766642  watermelon
# 2196   47.172328  watermelon
# 2197   56.127435  watermelon
# 2198   53.542556  watermelon
# 2199   43.140237  watermelon
#
# [2200 rows x 8 columns]

# %%
transformed_df.plot(kind = 'box', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Encoding

# %%
encoder = LabelEncoder()
encoded_label = encoder.fit_transform(transformed_df['label'])
encoded_df2 = transformed_df.assign(label = encoded_label)

# %%
encoded_df2
# Out:
#                N          P          K  temperature   humidity        ph  \
# 0      90.000000  42.000000  43.000000    20.879744  82.002744  6.502985
# 1      93.000000  56.000000  36.000000    24.014976  82.056872  6.984354
# 2      94.000000  50.000000  37.000000    25.665852  80.663850  6.948020
# 3      91.000000  35.000000  39.000000    23.793920  80.418180  6.970860
# 4      89.000000  45.000000  36.000000    21.325042  80.474764  6.442475
# ...          ...        ...        ...          ...        ...       ...
# 2195   83.536515  23.918535  51.691010    24.691443  81.200168  6.184308
# 2196  114.454431  20.010126  54.494937    25.970198  85.657426  6.782541
# 2197  112.749416  25.377046  54.374708    25.079361  86.134609  6.638630
# 2198   96.285352   9.750634  46.321338    25.546401  82.242377  6.427660
# 2199   98.721493   6.557014  46.671041    26.140777  86.542936  6.072931
#
#         rainfall  label
# 0     202.935536     20
# 1     185.277339     20
# 2     209.586971     20
# 3     206.261186     20
# 4     185.497473     20
# ...          ...    ...
# 2195   44.766642     21
# 2196   47.172328     21
# 2197   56.127435     21
# 2198   53.542556     21
# 2199   43.140237     21
#
# [2200 rows x 8 columns]

# %%
X = encoded_df2.drop(columns= ['label']).values
y = encoded_df2['label'].values

# %%
encoded_df2.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
target = ['label']

# %% [markdown]
# ## Splitting

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size= 0.20, random_state=7)

# %%
print('X_train shape', X_train.shape)
print('X_test shape', X_test.shape)
print('y_train shape', y_train.shape)
print('y_test shape', y_test.shape)
# Out:
# X_train shape (1760, 7)
# X_test shape (440, 7)
# y_train shape (1760,)
# y_test shape (440,)

# %% [markdown]
# ## Rescaling

# %%
scaler = MinMaxScaler().fit(X_train)
X_trainR = scaler.transform(X_train)
X_testR = scaler.transform(X_test)

# %%
X_trainR_df = pd.DataFrame(X_trainR, columns= features)
X_trainR_df
# Out:
#              N         P      K  temperature  humidity        ph  rainfall
# 0     0.285714  0.496063  0.060     0.868119  0.595450  0.850597  0.259160
# 1     0.428571  0.393701  0.175     0.467421  0.874019  0.662318  0.677797
# 2     0.285714  0.125984  0.015     0.902363  0.919900  0.766680  0.423251
# 3     0.000000  0.157480  0.045     0.219057  0.909388  0.484519  0.496873
# 4     0.742857  0.535433  0.205     0.649315  0.770611  0.463349  0.362642
# ...        ...       ...    ...          ...       ...       ...       ...
# 1755  0.342857  0.472441  0.365     0.135776  0.000941  0.884757  0.273021
# 1756  0.792857  0.354331  0.050     0.475021  0.772769  0.891009  0.332557
# 1757  0.100000  0.283465  0.060     0.648846  0.868475  0.677853  0.083840
# 1758  0.742857  0.157480  0.250     0.678798  0.890539  0.421026  0.012785
# 1759  0.264286  0.480315  0.400     0.289118  0.054465  0.509737  0.298714
#
# [1760 rows x 7 columns]

# %%
X_trainR_df.describe().T
# Out:
#               count      mean       std  min       25%       50%       75%  \
# N            1760.0  0.361272  0.261599  0.0  0.152553  0.264286  0.600000
# P            1760.0  0.374635  0.246631  0.0  0.181102  0.354331  0.496063
# K            1760.0  0.216471  0.254029  0.0  0.075000  0.135000  0.220000
# temperature  1760.0  0.494213  0.191678  0.0  0.370298  0.496924  0.626241
# humidity     1760.0  0.668112  0.262268  0.0  0.527135  0.777364  0.886234
# ph           1760.0  0.504136  0.178703  0.0  0.380553  0.496204  0.619695
# rainfall     1760.0  0.411893  0.250054  0.0  0.226850  0.383672  0.523759
#
#              max
# N            1.0
# P            1.0
# K            1.0
# temperature  1.0
# humidity     1.0
# ph           1.0
# rainfall     1.0

# %%
X_trainR_df.plot(kind = 'density', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %% [markdown]
# ## Normalizer

# %%
scaler = Normalizer().fit(X_trainR)
X_trainRN = scaler.transform(X_trainR)
X_testRN = scaler.transform(X_testR)

# %%
X_trainRN_df = pd.DataFrame(X_trainRN, columns= features)
X_trainRN_df
# Out:
#              N         P         K  temperature  humidity        ph  rainfall
# 0     0.191321  0.332175  0.040177     0.581312  0.398727  0.569578  0.173539
# 1     0.285729  0.262481  0.116673     0.311630  0.582710  0.441568  0.451888
# 2     0.179800  0.079282  0.009439     0.567856  0.578892  0.482471  0.266351
# 3     0.000000  0.133889  0.038259     0.186242  0.773160  0.411937  0.422440
# 4     0.496098  0.357575  0.136904     0.433629  0.514633  0.309436  0.242182
# ...        ...       ...       ...          ...       ...       ...       ...
# 1755  0.295112  0.406650  0.314171     0.116868  0.000810  0.761549  0.235001
# 1756  0.503061  0.224820  0.031725     0.301397  0.490316  0.565338  0.211005
# 1757  0.075903  0.215159  0.045542     0.492495  0.659201  0.514513  0.063637
# 1758  0.516273  0.109446  0.173746     0.471753  0.618909  0.292606  0.008886
# 1759  0.279177  0.507378  0.422538     0.305408  0.057534  0.538458  0.315545
#
# [1760 rows x 7 columns]

# %%
X_trainRN_df.describe().T
# Out:
#               count      mean       std  min       25%       50%       75%  \
# N            1760.0  0.267912  0.181427  0.0  0.120743  0.215734  0.435519
# P            1760.0  0.286131  0.174661  0.0  0.136084  0.267619  0.420889
# K            1760.0  0.151217  0.145849  0.0  0.067402  0.104816  0.155378
# temperature  1760.0  0.378821  0.153323  0.0  0.267139  0.369572  0.473844
# humidity     1760.0  0.491542  0.176179  0.0  0.434761  0.514146  0.615777
# ph           1760.0  0.387174  0.141625  0.0  0.291878  0.384442  0.474801
# rainfall     1760.0  0.312486  0.177838  0.0  0.155795  0.297661  0.445120
#
#                   max
# N            0.708066
# P            0.807370
# K            0.603200
# temperature  0.848722
# humidity     0.830933
# ph           0.777569
# rainfall     0.799317

# %%
X_trainRN_df.plot(kind = 'density', subplots = True, layout = [4,4], sharex = False, sharey = False, figsize = [20,25]);

# %%
X_trainRN_dfLabel = X_trainRN_df.copy()
X_trainRN_dfLabel['label'] = y_train

# %%
X_trainRN_dfLabel
# Out:
#              N         P         K  temperature  humidity        ph  rainfall  \
# 0     0.191321  0.332175  0.040177     0.581312  0.398727  0.569578  0.173539
# 1     0.285729  0.262481  0.116673     0.311630  0.582710  0.441568  0.451888
# 2     0.179800  0.079282  0.009439     0.567856  0.578892  0.482471  0.266351
# 3     0.000000  0.133889  0.038259     0.186242  0.773160  0.411937  0.422440
# 4     0.496098  0.357575  0.136904     0.433629  0.514633  0.309436  0.242182
# ...        ...       ...       ...          ...       ...       ...       ...
# 1755  0.295112  0.406650  0.314171     0.116868  0.000810  0.761549  0.235001
# 1756  0.503061  0.224820  0.031725     0.301397  0.490316  0.565338  0.211005
# 1757  0.075903  0.215159  0.045542     0.492495  0.659201  0.514513  0.063637
# 1758  0.516273  0.109446  0.173746     0.471753  0.618909  0.292606  0.008886
# 1759  0.279177  0.507378  0.422538     0.305408  0.057534  0.538458  0.315545
#
#       label
# 0         2
# 1         8
# 2        16
# 3        16
# 4         1
# ...     ...
# 1755      3
# 1756      6
# 1757     14
# 1758     15
# 1759      3
#
# [1760 rows x 8 columns]

# %%
X_trainRN_dfLabel.groupby('label').size()
# Out:
# label
# 0     79
# 1     83
# 2     78
# 3     80
# 4     79
# 5     79
# 6     76
# 7     82
# 8     80
# 9     83
# 10    75
# 11    81
# 12    87
# 13    79
# 14    85
# 15    83
# 16    81
# 17    79
# 18    77
# 19    81
# 20    78
# 21    75
# dtype: int64

# %% [markdown]
# ## Multicolinearity

# %%
corr = X_trainRN_dfLabel.corr()
plt.figure(figsize= [8,6])
sb.heatmap(corr, cmap= "YlGnBu", annot= True)
# Out:
# <Axes: >

# %%
X_train = X_trainRN
X_test = X_testRN

# %%
# Spot-Check Algorithms
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# %%
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, shuffle=True, random_state=7)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.836364 (0.024871)
# LDA: 0.935795 (0.015257)
# KNN: 0.957386 (0.018716)
# CART: 0.927273 (0.017932)
# NB: 0.976136 (0.010720)
# SVM: 0.955682 (0.015414)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
model = GaussianNB()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
# Evaluate the model and print the results
print(classification_report(y_test, predictions))
print('F1-score: ', f1_score(y_test, predictions,average='micro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        21
#            1       1.00      1.00      1.00        17
#            2       0.95      0.91      0.93        22
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        21
#            5       0.95      1.00      0.98        21
#            6       0.92      0.96      0.94        24
#            7       1.00      1.00      1.00        18
#            8       0.88      0.70      0.78        20
#            9       1.00      0.94      0.97        17
#           10       0.96      1.00      0.98        25
#           11       0.94      0.89      0.92        19
#           12       1.00      1.00      1.00        13
#           13       0.91      0.95      0.93        21
#           14       1.00      0.93      0.97        15
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        19
#           17       1.00      1.00      1.00        21
#           18       0.96      1.00      0.98        23
#           19       1.00      1.00      1.00        19
#           20       0.80      0.91      0.85        22
#           21       1.00      1.00      1.00        25
#
#     accuracy                           0.96       440
#    macro avg       0.97      0.96      0.96       440
# weighted avg       0.96      0.96      0.96       440
#
# F1-score:  0.9636363636363636

# %%
df2.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
def make_prediction(Nitrogen, Phosphorus, Calcium, temperature, humidity, ph, rainfall):
    data = {
        'Nitrogen': Nitrogen,
        'Posphorus': Phosphorus,
        'Calcium': Calcium,
        'temperature': temperature,
        'humidity': humidity,
        'ph': ph,
        'rainfall': rainfall,
    }
    
    df = pd.DataFrame(data, index=[0])
    
    # Assuming model is your trained model
    prediction = model.predict(df)
    
    # Inverse transform the predicted labels
    decoded_prediction = encoder.inverse_transform(prediction)
    
    return f"The crop that will do well: {decoded_prediction[0]}"

# %%
make_prediction(999, 355, 3777, 777, 44, 2, 12)
# Out:
# 'The crop that will do well: chickpea'

# %%
make_prediction(5, 10, 3, 777, 44, 2, 0)
# Out:
# 'The crop that will do well: orange'

# %%
df[df.isna().any(axis=1)]
# Out:
#           N      P      K  temperature   humidity        ph   rainfall  \
# 102    80.0   43.0   16.0    23.558821        NaN  6.657965  66.719955
# 107    89.0    NaN   19.0    25.191924  66.690290  5.913665  78.066396
# 111     NaN   49.0   21.0    24.840167  68.358457  6.472523  74.054749
# 268     NaN   56.0   85.0    20.118745  14.442283  6.817124  88.681686
# 1244   30.0    NaN  200.0    38.060995  82.247296  6.234904  65.701482
# 1268    8.0  133.0  195.0          NaN  80.975980  6.456080  71.298139
# 1292   25.0  129.0  195.0    17.986678  81.177121       NaN  72.371277
# 1316  119.0   25.0   51.0    26.473302        NaN  6.283818  53.657426
# 1338  120.0   19.0   49.0          NaN  84.268307  6.762472  56.452292
# 1362   85.0   25.0   47.0    26.114404  87.640811  6.295425        NaN
# 1371  110.0   28.0   46.0    24.291050        NaN  6.498896  51.260464
# 1392    NaN    7.0   45.0    26.706078  81.141495  6.944640  51.510336
# 1403   91.0    NaN   55.0    26.270616  83.091945  6.259087  46.768375
# 1415  120.0   24.0   47.0          NaN  89.413849  6.260839  58.548767
# 1427  115.0    9.0    NaN    29.067851  90.976855  6.019372  29.119474
# 1440    NaN   25.0   50.0    28.204808  92.914404  6.099662  20.360011
# 1446  100.0   17.0    NaN    29.727911  94.297533  6.367801  26.523641
#
#            label
# 102        maize
# 107        maize
# 111        maize
# 268     chickpea
# 1244      grapes
# 1268      grapes
# 1292      grapes
# 1316  watermelon
# 1338  watermelon
# 1362  watermelon
# 1371  watermelon
# 1392  watermelon
# 1403  watermelon
# 1415  watermelon
# 1427   muskmelon
# 1440   muskmelon
# 1446   muskmelon
